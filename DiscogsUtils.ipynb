# %%
import nltk
import os
import pandas as pd

from zipfile import ZipFile
import re
import pickle

# %% [markdown]
# ## Read data and do some pre-processing

# %%
# Read data 
zip_file = ZipFile('data/discogs/discogs_larger.zip')
dfs = {text_file.filename: pd.read_csv(zip_file.open(text_file.filename))
       for text_file in zip_file.infolist()
       if text_file.filename.endswith('.csv')}

discog_list = []
for key in dfs.keys():
    discog_list.append(pd.DataFrame(dfs.get(key)))

df = pd.concat(discog_list)

# Fix column formatting
df.release_descriptions = df.release_descriptions.apply(str)
df.styles = df.styles.apply(str)
df.genre = df.genre.apply(str)
df['labels'] = df['labels'].apply(str)
del df['Unnamed: 0']

# %%
# Create boolean columns for mixed and electronic albums

bool_mixed = []
for i in df.release_descriptions:
    bool_mixed.append('Mixed' in i)
df['bool_R_mixed'] = bool_mixed

bool_electronic = []
for i in df.genre:
    bool_electronic.append('Electronic' in i)
df['bool_R_electronic'] = bool_electronic

# %% [markdown]
# # Extract out styles for exploratory analysis

# %%
style_db = []
for i in df.styles:
    style_db.extend(re.sub(pattern='\[|\]|\'', repl='', string=i).split(', '))
from collections import Counter
counts = Counter(style_db)
print(counts)
# Out:
# Counter({'Techno': 78313, 'House': 77893, 'Tech House': 51076, 'Deep House': 37197, 'Electro': 27371, 'Minimal': 23848, 'Experimental': 20198, 'Ambient': 19388, 'Downtempo': 19023, 'Progressive House': 18720, 'Trance': 17537, 'Disco': 13523, 'IDM': 11653, 'Progressive Trance': 9043, 'Abstract': 8826, 'Hardcore': 8698, 'Breaks': 7434, 'Breakbeat': 7204, 'Acid': 7081, 'Gabber': 6840, 'Synth-pop': 6655, 'Leftfield': 6444, 'Dubstep': 6383, 'Drum n Bass': 6262, 'Hard Trance': 5686, 'Hip Hop': 5081, 'Garage House': 4870, 'Trip Hop': 4405, 'Future Jazz': 4190, 'Industrial': 4094, 'Hard House': 3626, 'Electro House': 3561, 'Dub Techno': 3462, 'nan': 3333, 'Indie Rock': 3043, 'Happy Hardcore': 2986, 'Acid House': 2921, 'Dub': 2912, 'Euro House': 2747, 'New Wave': 2493, 'UK Garage': 2295, 'Funk': 2276, 'Vaporwave': 2256, 'Tribal House': 1994, 'Contemporary': 1968, 'Grime': 1934, 'Soul': 1922, 'Psy-Trance': 1912, 'Glitch': 1892, 'Instrumental': 1889, 'Broken Beat': 1880, 'Modern Classical': 1858, 'EBM': 1776, 'Tribal': 1756, 'Alternative Rock': 1733, 'Minimal Techno': 1701, 'Latin': 1593, 'Noise': 1508, 'Italo-Disco': 1477, 'Pop Rock': 1346, 'Cut-up/DJ': 1340, 'Jungle': 1205, 'Bass Music': 1086, 'Heavy Metal': 1058, 'Folk': 1025, 'Punk': 1014, 'Drone': 1004, 'Interview': 963, 'Acid Jazz': 948, 'Black Metal': 935, 'Hardstyle': 911, 'Dark Ambient': 899, 'Nu-Disco': 860, 'Soundtrack': 850, 'Tech Trance': 804, 'Folk Rock': 770, 'Acoustic': 766, 'RnB/Swing': 745, 'Darkwave': 736, 'Big Beat': 723, 'Post Rock': 722, 'Hip-House': 717, 'Post-Punk': 708, 'Modern': 699, 'Rhythmic Noise': 668, 'Speedcore': 662, 'African': 657, 'Conscious': 649, 'Field Recording': 639, 'Goa Trance': 624, 'Deep Techno': 591, 'Psychedelic Rock': 580, 'Jazzdance': 579, 'Contemporary Jazz': 564, 'Trap': 530, 'Dancehall': 506, 'New Age': 489, 'Eurodance': 483, 'Progressive Breaks': 461, 'Musique Concrète': 459, 'Ghetto': 445, 'Death Metal': 440, 'J-pop': 439, 'Europop': 427, 'Hi NRG': 423, 'Pop Rap': 420, 'Freestyle': 407, 'Free Jazz': 403, 'Power Electronics': 396, 'Soul-Jazz': 392, 'Lo-Fi': 374, 'Juke': 372, 'Score': 348, 'Vocal': 345, 'Art Rock': 335, 'Avantgarde': 334, 'Ballad': 331, 'Speed Garage': 329, 'Prog Rock': 327, 'Afrobeat': 321, 'Chiptune': 318, 'Krautrock': 316, 'Goth Rock': 313, 'New Beat': 313, 'Free Improvisation': 304, 'Ska': 301, 'Fusion': 291, 'Ragga HipHop': 286, 'Reggae': 285, 'Glam': 285, 'Rock & Roll': 279, 'Indie Pop': 278, 'Jazz-Funk': 276, 'Jumpstyle': 275, 'Rhythm & Blues': 271, 'Hard Rock': 264, 'Calypso': 263, 'Tropical House': 262, 'Classic Rock': 258, 'Doomcore': 257, 'Thrash': 256, 'Spoken Word': 253, 'Boogie': 246, 'Neo Soul': 246, 'Lounge': 243, 'Shoegaze': 242, 'Italodance': 241, 'Breakcore': 233, 'Jazzy Hip-Hop': 232, 'Dance-pop': 227, 'Latin Jazz': 225, 'Synthwave': 219, 'Contemporary R&B': 217, 'Education': 216, 'Ghetto House': 209, 'Neofolk': 202, 'Chillwave': 201, 'Easy Listening': 199, 'Hard Techno': 193, 'Bossa Nova': 186, 'Math Rock': 185, 'Berlin-School': 183, 'Gospel': 182, 'Bassline': 181, 'Avant-garde Jazz': 178, 'Post-Modern': 178, 'Garage Rock': 177, 'Brit Pop': 177, 'Highlife': 173, 'Monolog': 172, 'Gangsta': 171, 'Illbient': 163, 'Space-Age': 161, 'Bossanova': 160, 'Doom Metal': 156, 'Comedy': 155, 'Special Effects': 150, 'Ethereal': 147, 'Speed Metal': 147, 'Electroclash': 145, 'Roots Reggae': 142, 'Afro-Cuban Jazz': 142, 'Afro-Cuban': 139, 'Rumba': 138, 'Ragga': 137, 'Symphonic Rock': 129, 'Soft Rock': 125, 'Smooth Jazz': 122, 'Salsa': 118, 'Samba': 117, 'Big Band': 115, 'Jazz-Rock': 112, 'Thug Rap': 110, 'Reggae-Pop': 108, 'Classical': 107, 'Beatdown': 104, 'Bounce': 103, 'Crunk': 103, 'Cubano': 101, 'Swing': 101, 'Neo-Classical': 98, 'Musical': 91, 'Power Metal': 89, 'Blues Rock': 89, 'Opera': 88, 'MPB': 88, 'Schlager': 86, 'Country': 86, 'Brass Band': 79, 'Gothic Metal': 78, 'Ragtime': 76, 'Radioplay': 76, 'Bop': 75, 'Novelty': 75, 'Power Pop': 72, 'Modal': 70, 'Poetry': 70, 'Country Blues': 69, 'Son': 64, 'Coldwav ...

# %%
# Remove styles that aren't useful for DJing
delete_these = []
for i in counts:
    if re.search(pattern='Rock|Metal|Parody|Folk|Krautrock|Score|J-pop|Pop|Instrumental|Lounge|Free Jazz|nan|Free Improvisation|Rhythm \& Blues|Modern Classical|Punk|Interview|Thrash|Shoegaze|Education|Spoken Word|Acoustic|Neofolk|Field Recording', 
                 string=i) is not None:
        delete_these.append(i)

# %%
for i in delete_these:
    counts.pop(i)

# %%
counts.most_common(100)
# Out:
# [('Techno', 78313),
#  ('House', 77893),
#  ('Tech House', 51076),
#  ('Deep House', 37197),
#  ('Electro', 27371),
#  ('Minimal', 23848),
#  ('Experimental', 20198),
#  ('Ambient', 19388),
#  ('Downtempo', 19023),
#  ('Progressive House', 18720),
#  ('Trance', 17537),
#  ('Disco', 13523),
#  ('IDM', 11653),
#  ('Progressive Trance', 9043),
#  ('Abstract', 8826),
#  ('Hardcore', 8698),
#  ('Breaks', 7434),
#  ('Breakbeat', 7204),
#  ('Acid', 7081),
#  ('Gabber', 6840),
#  ('Synth-pop', 6655),
#  ('Leftfield', 6444),
#  ('Dubstep', 6383),
#  ('Drum n Bass', 6262),
#  ('Hard Trance', 5686),
#  ('Hip Hop', 5081),
#  ('Garage House', 4870),
#  ('Trip Hop', 4405),
#  ('Future Jazz', 4190),
#  ('Industrial', 4094),
#  ('Hard House', 3626),
#  ('Electro House', 3561),
#  ('Dub Techno', 3462),
#  ('Happy Hardcore', 2986),
#  ('Acid House', 2921),
#  ('Dub', 2912),
#  ('Euro House', 2747),
#  ('New Wave', 2493),
#  ('UK Garage', 2295),
#  ('Funk', 2276),
#  ('Vaporwave', 2256),
#  ('Tribal House', 1994),
#  ('Contemporary', 1968),
#  ('Grime', 1934),
#  ('Soul', 1922),
#  ('Psy-Trance', 1912),
#  ('Glitch', 1892),
#  ('Broken Beat', 1880),
#  ('EBM', 1776),
#  ('Tribal', 1756),
#  ('Minimal Techno', 1701),
#  ('Latin', 1593),
#  ('Noise', 1508),
#  ('Italo-Disco', 1477),
#  ('Cut-up/DJ', 1340),
#  ('Jungle', 1205),
#  ('Bass Music', 1086),
#  ('Drone', 1004),
#  ('Acid Jazz', 948),
#  ('Hardstyle', 911),
#  ('Dark Ambient', 899),
#  ('Nu-Disco', 860),
#  ('Soundtrack', 850),
#  ('Tech Trance', 804),
#  ('RnB/Swing', 745),
#  ('Darkwave', 736),
#  ('Big Beat', 723),
#  ('Hip-House', 717),
#  ('Modern', 699),
#  ('Rhythmic Noise', 668),
#  ('Speedcore', 662),
#  ('African', 657),
#  ('Conscious', 649),
#  ('Goa Trance', 624),
#  ('Deep Techno', 591),
#  ('Jazzdance', 579),
#  ('Contemporary Jazz', 564),
#  ('Trap', 530),
#  ('Dancehall', 506),
#  ('New Age', 489),
#  ('Eurodance', 483),
#  ('Progressive Breaks', 461),
#  ('Musique Concrète', 459),
#  ('Ghetto', 445),
#  ('Europop', 427),
#  ('Hi NRG', 423),
#  ('Freestyle', 407),
#  ('Power Electronics', 396),
#  ('Soul-Jazz', 392),
#  ('Lo-Fi', 374),
#  ('Juke', 372),
#  ('Vocal', 345),
#  ('Avantgarde', 334),
#  ('Ballad', 331),
#  ('Speed Garage', 329),
#  ('Afrobeat', 321),
#  ('Chiptune', 318),
#  ('New Beat', 313),
#  ('Ska', 301),
#  ('Fusion', 291)]

# %% [markdown]
# As we can see there are far too many genres/styles at the moment. We will filter to only include albums that are "Electronic"

# %%
#filter for only electronic music
df = df.reset_index(drop = True)
df = pd.DataFrame(df)
df = df[df['bool_R_electronic']]

# %%
style_db = []
for i in df.styles:
    style_db.extend(re.sub(pattern='\[|\]|\'', repl='', string=i).split(', '))
from collections import Counter
counts = Counter(style_db)
#print(counts)
# Remove styles that aren't useful for DJing
delete_these = []
for i in counts:
    if re.search(pattern='Rock|Metal|Parody|Folk|Krautrock|Score|J-pop|Pop|Instrumental|Lounge|Free Jazz|nan|Free Improvisation|Rhythm \& Blues|Modern Classical|Punk|Interview|Thrash|Shoegaze|Education|Spoken Word|Acoustic|Neofolk|Field Recording', 
                 string=i) is not None:
        delete_these.append(i)
for i in delete_these:
    counts.pop(i)
counts.most_common(100)
# Out:
# [('Techno', 78300),
#  ('House', 77893),
#  ('Tech House', 51076),
#  ('Deep House', 37197),
#  ('Electro', 27363),
#  ('Minimal', 23814),
#  ('Experimental', 19846),
#  ('Ambient', 19380),
#  ('Downtempo', 18958),
#  ('Progressive House', 18720),
#  ('Trance', 17537),
#  ('Disco', 13022),
#  ('IDM', 11653),
#  ('Progressive Trance', 9043),
#  ('Abstract', 8810),
#  ('Hardcore', 8440),
#  ('Breaks', 7384),
#  ('Breakbeat', 7199),
#  ('Acid', 7081),
#  ('Gabber', 6840),
#  ('Synth-pop', 6655),
#  ('Leftfield', 6432),
#  ('Dubstep', 6383),
#  ('Drum n Bass', 6262),
#  ('Hard Trance', 5686),
#  ('Hip Hop', 5060),
#  ('Garage House', 4870),
#  ('Trip Hop', 4382),
#  ('Future Jazz', 4186),
#  ('Industrial', 4076),
#  ('Hard House', 3626),
#  ('Electro House', 3561),
#  ('Dub Techno', 3449),
#  ('Happy Hardcore', 2986),
#  ('Acid House', 2921),
#  ('Euro House', 2747),
#  ('Dub', 2744),
#  ('UK Garage', 2295),
#  ('Vaporwave', 2256),
#  ('New Wave', 2118),
#  ('Tribal House', 1994),
#  ('Grime', 1934),
#  ('Funk', 1913),
#  ('Psy-Trance', 1912),
#  ('Glitch', 1892),
#  ('Broken Beat', 1880),
#  ('EBM', 1776),
#  ('Tribal', 1733),
#  ('Minimal Techno', 1701),
#  ('Latin', 1590),
#  ('Soul', 1535),
#  ('Italo-Disco', 1477),
#  ('Noise', 1476),
#  ('Jungle', 1205),
#  ('Bass Music', 1085),
#  ('Cut-up/DJ', 1025),
#  ('Drone', 1002),
#  ('Acid Jazz', 948),
#  ('Hardstyle', 911),
#  ('Dark Ambient', 899),
#  ('Nu-Disco', 857),
#  ('Tech Trance', 804),
#  ('Darkwave', 736),
#  ('Soundtrack', 727),
#  ('Big Beat', 723),
#  ('Hip-House', 717),
#  ('Rhythmic Noise', 668),
#  ('Speedcore', 662),
#  ('Goa Trance', 624),
#  ('RnB/Swing', 592),
#  ('Deep Techno', 591),
#  ('Jazzdance', 564),
#  ('Trap', 530),
#  ('Contemporary', 504),
#  ('New Age', 489),
#  ('Eurodance', 483),
#  ('Progressive Breaks', 461),
#  ('Musique Concrète', 452),
#  ('Ghetto', 445),
#  ('Conscious', 440),
#  ('Dancehall', 419),
#  ('Freestyle', 407),
#  ('Hi NRG', 406),
#  ('Power Electronics', 396),
#  ('Juke', 372),
#  ('Speed Garage', 329),
#  ('Chiptune', 318),
#  ('New Beat', 313),
#  ('Europop', 313),
#  ('Soul-Jazz', 300),
#  ('Avantgarde', 299),
#  ('Lo-Fi', 299),
#  ('Vocal', 287),
#  ('Jumpstyle', 275),
#  ('African', 268),
#  ('Tropical House', 262),
#  ('Doomcore', 257),
#  ('Italodance', 241),
#  ('Breakcore', 233),
#  ('Ballad', 231)]

# %% [markdown]
# ## Create booleans for genres, separating mixed albums from regular releases

# %%
def search_release_genres(genre_extract, genre_search_release):
    search_results = {}
    for i in genre_search:
        if re.search(pattern=i, string=str(genre_extract)):
            search_results['bool_R_%s' % i.replace(" ", "_")] = True
        else:
            search_results['bool_R_%s' % i.replace(" ", "_")] = False
    return(search_results)

# %%
genre_search_release = ['Techno', 'House', 'Tech House','Trance', 'Disco', 
                'Psy-Trance', 'Electro', 'IDM', 'Drum n Bass', 'Garage',
                'Hard', 'Progressive', 'Acid', 'Deep', 'Minimal', 'Dub', 'Industrial', 'Hip Hop', 'Funk',
                   'Leftfield', 'Abstract', 'Experimental']

# %%
df = df.reset_index(drop = True)
compiled_genres = []
for i in range(0, len(df)):
    compiled_genres.append(search_release_genres(df['styles'][i], genre_search_release))

# %%
compiled_genres = pd.DataFrame(compiled_genres)

# %%
df = pd.concat([df.reset_index(drop=True), compiled_genres.reset_index(drop = True)], axis=1)

# %%
#for i,j in counts.most_common(100):
#    h = re.sub(pattern=' ', repl='_', string=i)
#    x=('bool_R_%s' % h) 
#    y=[]
#    for j in df.styles:
#        y.append(i in j)
#    print('Applied style %s' % i )
#    df[x] = y

# %%
# Split mixed releases from regular ones
df_mixed = df[df['bool_R_mixed'] == True]
df_mixed = df_mixed.reset_index(drop=True)
df_releases = df[df['bool_R_mixed'] == False]
df_releases = df_releases.reset_index(drop=True)

# %%
df_releases.head(n=25)
# Out:
#                  artist   cat_no country           genre  \
# 0        Unknown Artist      303      UK  ['Electronic']
# 1        Unknown Artist      303      UK  ['Electronic']
# 2        Unknown Artist      303      UK  ['Electronic']
# 3        Unknown Artist      303      UK  ['Electronic']
# 4               Ausgang  BR001LP      UK  ['Electronic']
# 5                Vector  BR001LP      UK  ['Electronic']
# 6   The Fatima Mansions  BR001LP      UK  ['Electronic']
# 7              Spectral  BR001LP      UK  ['Electronic']
# 8        Virtuality (2)  BR001LP      UK  ['Electronic']
# 9                Har-El  BR001LP      UK  ['Electronic']
# 10                 Moog  BR001LP      UK  ['Electronic']
# 11    Astral Projection  BR001LP      UK  ['Electronic']
# 12        Voodoo People  BR001LP      UK  ['Electronic']
# 13        Total Eclipse  BR001LP      UK  ['Electronic']
# 14       Cari Lekebusch  HYB 001  Sweden  ['Electronic']
# 15       Cari Lekebusch  HYB 001  Sweden  ['Electronic']
# 16       Cari Lekebusch  HYB 001  Sweden  ['Electronic']
# 17       Cari Lekebusch  HYB 002  Sweden  ['Electronic']
# 18       Cari Lekebusch  HYB 002  Sweden  ['Electronic']
# 19       Cari Lekebusch  HYB 002  Sweden  ['Electronic']
# 20       Drumtravellers  HYB 003  Sweden  ['Electronic']
# 21       Drumtravellers  HYB 003  Sweden  ['Electronic']
# 22       Crushed Insect  HYB 004  Sweden  ['Electronic']
# 23       Crushed Insect  HYB 004  Sweden  ['Electronic']
# 24       Cari Lekebusch  HYB 005  Sweden  ['Electronic']
#
#                label_root                     labels length position  \
# 0   Planet Rhythm Records  ['Planet Rhythm Records']    NaN       A1
# 1   Planet Rhythm Records  ['Planet Rhythm Records']    NaN       A2
# 2   Planet Rhythm Records  ['Planet Rhythm Records']    NaN       B1
# 3   Planet Rhythm Records  ['Planet Rhythm Records']    NaN       B2
# 4   Planet Rhythm Records     ['Blue Room Released']   7:13       A1
# 5   Planet Rhythm Records     ['Blue Room Released']   5:35       A2
# 6   Planet Rhythm Records     ['Blue Room Released']   7:23       B1
# 7   Planet Rhythm Records     ['Blue Room Released']   6:58       B2
# 8   Planet Rhythm Records     ['Blue Room Released']   6:11       C1
# 9   Planet Rhythm Records     ['Blue Room Released']   6:36       C2
# 10  Planet Rhythm Records     ['Blue Room Released']   7:48       D1
# 11  Planet Rhythm Records     ['Blue Room Released']   9:21       D2
# 12  Planet Rhythm Records     ['Blue Room Released']   6:06        E
# 13  Planet Rhythm Records     ['Blue Room Released']   6:35        F
# 14  Planet Rhythm Records                 ['Hybrid']   8:55       A1
# 15  Planet Rhythm Records                 ['Hybrid']   7:06       A2
# 16  Planet Rhythm Records                 ['Hybrid']   9:56        B
# 17  Planet Rhythm Records                 ['Hybrid']    NaN       A1
# 18  Planet Rhythm Records                 ['Hybrid']    NaN       A2
# 19  Planet Rhythm Records                 ['Hybrid']    NaN        B
# 20  Planet Rhythm Records                 ['Hybrid']  12:02        A
# 21  Planet Rhythm Records                 ['Hybrid']  13:58        B
# 22  Planet Rhythm Records                 ['Hybrid']    NaN        A
# 23  Planet Rhythm Records                 ['Hybrid']    NaN        B
# 24  Planet Rhythm Records                 ['Hybrid']    NaN       A1
#
#                                             release  release_artist  \
# 0                                            303 EP  Unknown Artist
# 1                                            303 EP  Unknown Artist
# 2                                            303 EP  Unknown Artist
# 3                                            303 EP  Unknown Artist
# 4   Blue Room Released Vol: 1 - Outside The Reactor         Various
# 5   Blue Room Released Vol: 1 - Outside The Reactor         Various
# 6   Blue Room Released Vol: 1 - Outside The Reactor         Various
# 7   Blue Room Released Vol: 1 - Outside The Reactor         Various
# 8   Blue Room Released Vol: 1 - Outside The Reactor         Various
# 9   Blue Room Released Vol: 1 - Outside The Reactor         Various
# 10  Blue Room Released Vol: 1 - Outside The Reactor         Various
# 11  Blue Room Released Vol: 1 - Outside The Reactor         Various
# 12  Blue Room Released Vol: 1 - Outside The Reactor         Various
# 13  Blue Room Released Vol: 1 - Outside The Reactor         Various
# 14                                         Output 1  Cari Lekebusch
# 15                                         Output 1  Cari Lekebusch
# 16                                         Output 1  Cari Lekebusch
# 17                                         Output 2  Cari Lekebusch
# 18                                         Output 2  Cari Lekebusch
# 19                                         Output 2  Cari Lekebusch
# 20                                            Vol 1  Drumtravellers
# 21                                            Vol 1  Drumtravellers
# 22                          Put Me On Your Sandwich  Crushed Insect
# 23                          Put Me On Your Sandwich  Crushed Insect
# 24                             Drum And Noise Style  Cari Lekebusch
#
#         ...       bool_R_House bool_R_IDM bool_R_Industrial bool_R_Leftfield  \
# 0       ...              False      False             False            False
# 1       ...              False      False             False            False
# 2       ...              False      False             False            False
# 3       ...              False      False             False            False
# 4       ...              False      False             False            False
# 5       ...              False      False             False            False
# 6       ...              False      False             False            False
# 7       ...              False      False             False            False
# 8       ...              False      False             False            False
# 9       ...              False      False             False            False
# 10      ...              False      False             False            False
# 11      ...              False      False             False            False
# 12      ...              False      False             False            False
# 13      ...              False      False             False            False
# 14      ...              False      False             False            False
# 15      ...              False      False             False            False
# 16      ...              False      False             False            False
# 17      ...              False      False             False            False
# 18      ...              False      False             False            False
# 19      ...              False      False             False            False
# 20      ...              False      False             False            False
# 21      ...              False      False             False            False
# 22      ...              False      False             False            False
# 23      ...              False      False             False            False
# 24      ...              False      False             False            False
#
#     bool_R_Minimal  bool_R_Progressive  bool_R_Psy-Trance  bool_R_Tech_House  \
# 0            False               False              False              False
# 1            False               False              False              False
# 2            False               False              False              False
# 3            False               False              False              False
# 4            False               False              False              False
# 5            False               False              False              False
# 6            False               False              False              False
# 7            False               False              False              False
# 8            False               False              False              False
# 9            False               False              False              False
# 10           False               False              False              False
# 11           False               False              False              False
# 12           False               False              False              False
# 13           False               False              False              False
# 14            True               False              False              False
# 15            True               False              False              False
# 16            True               False              False              False
# 17           False               False              False              False
# 18           False               False              False              False
# 19           False               False              False              False
# 20           False               False              False              False
# 21           False               False              False              False
# 22           False               False              False              False
# 23           False               False              False              False
# 24            True               False              False              False
#
#     bool_R_Techno  bool_R_Trance
# 0            True          False
# 1            True          False
# 2            True          False
# 3            True          False
# 4           False           True
# 5           False           True
# 6           False           True
# 7           False           True
# 8           False           True
# 9           False           True
# 10          False           True
# 11          False           True
# 12          False           True
# 13          False           True
# 14           True          False
# 15           True          False
# 16           True          False
# 17           True          False
# 18           True          False
# 19           True          False
# 20           True          False
# 21           True          False
# 22           True          False
# 23           True          False
# 24           True          False
#
# [25 rows x 39 columns]

# %%
df_mixed.head(n=25)
# Out:
#                  artist            cat_no country           genre  \
# 0                Vector        EKCY-10001   Japan  ['Electronic']
# 1                Vector        EKCY-10001   Japan  ['Electronic']
# 2                Vector        EKCY-10001   Japan  ['Electronic']
# 3                Vector        EKCY-10001   Japan  ['Electronic']
# 4            Adam Beyer        EKCY-10001   Japan  ['Electronic']
# 5            Adam Beyer        EKCY-10001   Japan  ['Electronic']
# 6            Adam Beyer        EKCY-10001   Japan  ['Electronic']
# 7   R.N.D. Technologies        EKCY-10001   Japan  ['Electronic']
# 8          Thomas Krome        EKCY-10001   Japan  ['Electronic']
# 9         Abstract Soul        EKCY-10001   Japan  ['Electronic']
# 10  R.N.D. Technologies        EKCY-10001   Japan  ['Electronic']
# 11           Adam Beyer        EKCY-10001   Japan  ['Electronic']
# 12          Wave Slaves        EKCY-10001   Japan  ['Electronic']
# 13            Rotortype        EKCY-10001   Japan  ['Electronic']
# 14    Gabriel & Dresden  0 6700 30367 2 6  Canada  ['Electronic']
# 15    Gabriel & Dresden  0 6700 30367 2 6  Canada  ['Electronic']
# 16    Gabriel & Dresden  0 6700 30367 2 6  Canada  ['Electronic']
# 17               Andain  0 6700 30367 2 6  Canada  ['Electronic']
# 18    Michael Burns (3)  0 6700 30367 2 6  Canada  ['Electronic']
# 19      Sarah McLachlan  0 6700 30367 2 6  Canada  ['Electronic']
# 20          Audioholics  0 6700 30367 2 6  Canada  ['Electronic']
# 21              Voyager  0 6700 30367 2 6  Canada  ['Electronic']
# 22    Gabriel & Dresden  0 6700 30367 2 6  Canada  ['Electronic']
# 23               Ferenc  0 6700 30367 2 6  Canada  ['Electronic']
# 24           Guy Gerber  0 6700 30367 2 6  Canada  ['Electronic']
#
#                label_root                            labels length position  \
# 0   Planet Rhythm Records  ['EPS', 'Planet Rhythm Records']    NaN        1
# 1   Planet Rhythm Records  ['EPS', 'Planet Rhythm Records']    NaN        2
# 2   Planet Rhythm Records  ['EPS', 'Planet Rhythm Records']    NaN        3
# 3   Planet Rhythm Records  ['EPS', 'Planet Rhythm Records']    NaN        4
# 4   Planet Rhythm Records  ['EPS', 'Planet Rhythm Records']    NaN        5
# 5   Planet Rhythm Records  ['EPS', 'Planet Rhythm Records']    NaN        6
# 6   Planet Rhythm Records  ['EPS', 'Planet Rhythm Records']    NaN        7
# 7   Planet Rhythm Records  ['EPS', 'Planet Rhythm Records']    NaN        8
# 8   Planet Rhythm Records  ['EPS', 'Planet Rhythm Records']    NaN        9
# 9   Planet Rhythm Records  ['EPS', 'Planet Rhythm Records']    NaN       10
# 10  Planet Rhythm Records  ['EPS', 'Planet Rhythm Records']    NaN       11
# 11  Planet Rhythm Records  ['EPS', 'Planet Rhythm Records']    NaN       12
# 12  Planet Rhythm Records  ['EPS', 'Planet Rhythm Records']    NaN       13
# 13  Planet Rhythm Records  ['EPS', 'Planet Rhythm Records']    NaN       14
# 14        Bedrock Records                      ['Nettwerk']   8:28     1.01
# 15        Bedrock Records                      ['Nettwerk']   8:13     1.02
# 16        Bedrock Records                      ['Nettwerk']   8:14     1.03
# 17        Bedrock Records                      ['Nettwerk']   4:52     1.04
# 18        Bedrock Records                      ['Nettwerk']   7:43     1.05
# 19        Bedrock Records                      ['Nettwerk']  10:01     1.06
# 20        Bedrock Records                      ['Nettwerk']   4:25     1.07
# 21        Bedrock Records                      ['Nettwerk']   4:38     1.08
# 22        Bedrock Records                      ['Nettwerk']   6:58     1.09
# 23        Bedrock Records                      ['Nettwerk']   5:45     1.10
# 24        Bedrock Records                      ['Nettwerk']   9:56     1.11
#
#                                    release     release_artist      ...        \
# 0   Planet Rhythm Label Collection Vol.001            Various      ...
# 1   Planet Rhythm Label Collection Vol.001            Various      ...
# 2   Planet Rhythm Label Collection Vol.001            Various      ...
# 3   Planet Rhythm Label Collection Vol.001            Various      ...
# 4   Planet Rhythm Label Collection Vol.001            Various      ...
# 5   Planet Rhythm Label Collection Vol.001            Various      ...
# 6   Planet Rhythm Label Collection Vol.001            Various      ...
# 7   Planet Rhythm Label Collection Vol.001            Various      ...
# 8   Planet Rhythm Label Collection Vol.001            Various      ...
# 9   Planet Rhythm Label Collection Vol.001            Various      ...
# 10  Planet Rhythm Label Collection Vol.001            Various      ...
# 11  Planet Rhythm Label Collection Vol.001            Various      ...
# 12  Planet Rhythm Label Collection Vol.001            Various      ...
# 13  Planet Rhythm Label Collection Vol.001            Various      ...
# 14                                   Bloom  Gabriel & Dresden      ...
# 15                                   Bloom  Gabriel & Dresden      ...
# 16                                   Bloom  Gabriel & Dresden      ...
# 17                                   Bloom  Gabriel & Dresden      ...
# 18                                   Bloom  Gabriel & Dresden      ...
# 19                                   Bloom  Gabriel & Dresden      ...
# 20                                   Bloom  Gabriel & Dresden      ...
# 21                                   Bloom  Gabriel & Dresden      ...
# 22                                   Bloom  Gabriel & Dresden      ...
# 23                                   Bloom  Gabriel & Dresden      ...
# 24                                   Bloom  Gabriel & Dresden      ...
#
#    bool_R_House bool_R_IDM bool_R_Industrial bool_R_Leftfield  bool_R_Minimal  \
# 0         False      False             False            False            True
# 1         False      False             False            False            True
# 2         False      False             False            False            True
# 3         False      False             False            False            True
# 4         False      False             False            False            True
# 5         False      False             False            False            True
# 6         False      False             False            False            True
# 7         False      False             False            False            True
# 8         False      False             False            False            True
# 9         False      False             False            False            True
# 10        False      False             False            False            True
# 11        False      False             False            False            True
# 12        False      False             False            False            True
# 13        False      False             False            False            True
# 14         True      False             False            False           False
# 15         True      False             False            False           False
# 16         True      False             False            False           False
# 17         True      False             False            False           False
# 18         True      False             False            False           False
# 19         True      False             False            False           False
# 20         True      False             False            False           False
# 21         True      False             False            False           False
# 22         True      False             False            False           False
# 23         True      False             False            False           False
# 24         True      False             False            False           False
#
#     bool_R_Progressive  bool_R_Psy-Trance  bool_R_Tech_House  bool_R_Techno  \
# 0                False              False              False           True
# 1                False              False              False           True
# 2                False              False              False           True
# 3                False              False              False           True
# 4                False              False              False           True
# 5                False              False              False           True
# 6                False              False              False           True
# 7                False              False              False           True
# 8                False              False              False           True
# 9                False              False              False           True
# 10               False              False              False           True
# 11               False              False              False           True
# 12               False              False              False           True
# 13               False              False              False           True
# 14                True              False              False          False
# 15                True              False              False          False
# 16                True              False              False          False
# 17                True              False              False          False
# 18                True              False              False          False
# 19                True              False              False          False
# 20                True              False              False          False
# 21                True              False              False          False
# 22                True              False              False          False
# 23                True              False              False          False
# 24                True              False              False          False
#
#     bool_R_Trance
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# 5           False
# 6           False
# 7           False
# 8           False
# 9           False
# 10          False
# 11          False
# 12          False
# 13          False
# 14           True
# 15           True
# 16           True
# 17           True
# 18           True
# 19           True
# 20           True
# 21           True
# 22           True
# 23           True
# 24           True
#
# [25 rows x 39 columns]

# %%
df_mixed.to_csv('discogs_mixed.csv')
df_releases.to_csv('discogs_releases.csv')
